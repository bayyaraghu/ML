# %%
# Building pipeline using pandas

# %%
import pandas as pd

# %%
housing = pd.read_csv('USA_housing.csv')

housing.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
#EDA
housing['Area Population'].unique()
# Out:
# array([23086.80050269, 40173.07217364, 36882.1593997 , ...,
#        33266.14548965, 42625.62015585, 46501.28380314])

# %%
housing.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
# Adding the new column in dataset using function inside if statemetns

def size(n):
    if n<4:
        return "Small"
    elif 4<n<6:
        return "Medium"
    else:
        return "Big"
housing['House_size']=housing['Avg. Area Number of Rooms'].apply(size)

# %%
housing.head()
housing.loc[housing.House_size == 'Big']
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 4         59982.197226             5.040555                   7.839388
# 5         80175.754159             4.988408                   6.104512
# ...                ...                  ...                        ...
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 4                             4.23     26354.109472  6.309435e+05
# 5                             4.04     26748.428425  1.068138e+06
# ...                            ...              ...           ...
# 4994                          4.16     22695.695480  9.053549e+05
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address House_size
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...        Big
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...        Big
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...        Big
# 4                            USNS Raymond\nFPO AE 09386        Big
# 5     06039 Jennifer Islands Apt. 443\nTracyport, KS...        Big
# ...                                                 ...        ...
# 4994             5224 Lamb Passage\nNancystad, GA 16579        Big
# 4995                   USNS Williams\nFPO AP 30153-7653        Big
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352        Big
# 4998                          USS Wallace\nFPO AE 73316        Big
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...        Big
#
# [4171 rows x 8 columns]

# %%
import pdpipe as pdp

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+=pdp.OneHotEncode('House_size')
df3=pipeline(housing)

# %%
df3.head()
# Out:
#    Avg. Area Income  Avg. Area Number of Rooms  Avg. Area Number of Bedrooms  \
# 0      79545.458574                   7.009188                          4.09
# 1      79248.642455                   6.730821                          3.09
# 2      61287.067179                   8.512727                          5.13
# 3      63345.240046                   5.586729                          3.26
# 4      59982.197226                   7.839388                          4.23
#
#    Area Population         Price  \
# 0     23086.800503  1.059034e+06
# 1     40173.072174  1.505891e+06
# 2     36882.159400  1.058988e+06
# 3     34310.242831  1.260617e+06
# 4     26354.109472  6.309435e+05
#
#                                              Address  House_size_Medium  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...                  0
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...                  0
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...                  0
# 3                          USS Barnett\nFPO AP 44820                  1
# 4                         USNS Raymond\nFPO AE 09386                  0
#
#    House_size_Small
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
def price_tag(x):
    if x > 250000:
        return 'keep'
    else:
        return 'drop'
    
pipeline+=pdp.ApplyByCols('Price', price_tag, 'Price_tag', drop=False)
pipeline+=pdp.ValDrop(['drop'], 'Price_tag')
pipeline+=pdp.ColDrop('Price_tag')
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-33-3dfbd29381fc> in <module>
#       8 pipeline+=pdp.ValDrop(['drop'], 'Price_tag')
#       9 pipeline+=pdp.ColDrop('Price_tag')
# ---> 10 df5 = pipeline(df3)
#      11 df5.head()
#
# ~\Anaconda3\lib\site-packages\pdpipe\core.py in apply(self, df, exraise, verbose)
#     387         inter_df = df
#     388         for stage in self._stages:
# --> 389             inter_df = stage.apply(inter_df, exraise, verbose)
#     390         return inter_df
#     391
#
# ~\Anaconda3\lib\site-packages\pdpipe\core.py in apply(self, df, exraise, verbose)
#     157             return self._fit_transform(df, verbose=verbose)
#     158         if exraise:
# --> 159             raise FailedPreconditionError(self._exmsg)
#     160         return df
#     161
#
# FailedPreconditionError: ColDrop stage failed because not all columns Avg. Area House Age were found in input dataframe.
